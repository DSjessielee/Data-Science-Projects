# %% [markdown]
# # Covid Vaccine Coverage Prediction - an Update
# This project is to use the themes of each county in United States to predict the outcome of vaccine coverage.
# The target is to predict the vaccine rate, which is updated daily. We used the data up to 7/21/2021 for calibration
# The purpose if to identify the area of concerns

# %%
from pandas import Series, DataFrame
import pandas as pd
# %pylab inline
import IPython
import pandas as pd
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import sklearn as sk
import statsmodels.formula.api as smf
import statsmodels.api as sm
import os
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from matplotlib.lines import Line2D
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import time
from pandas import Series, DataFrame
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %%
#Daily vaccination administration data from cdc up to 7/31
#source:https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc
vac_admin = pd.read_csv('vac_county.csv')

#Vaccination hesitance survey result by states and county
#source: https://data.cdc.gov/stories/s/cnd2-a6zw
vac_h = pd.read_csv('vac_hesi_county.csv')
vac_h=vac_h.dropna()

#Vaccination coverage index by states and county
#source:https://vaccine.precisionforcovid.org/
vac_c = pd.read_csv('cvac_county.csv')
vac_c_sub=pd.read_csv('cvac_sub_county.csv')

#2020 Us census data for state population
#source: https://www.census.gov/data/tables/2020/dec/2020-apportionment-data.html
# pop = pd.read_csv('pop_county.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,23,24,25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

def state_abbrev(x):
    
    '''
    This function converts full US tates name into abbreviated version.
    '''
    for key, value in us_state_abbrev.items():
        if x==key:
            return value

def state_full(x):
    '''
    This function converts abbreviated US tates name into full version.
    '''
    for key, value in us_state_abbrev.items():
        if x==value:
            return key

# %%
vac_admin
vac_admin['state_county'] = vac_admin['Recip_State'].str.lower() + '_' + vac_admin['Recip_County'].str.lower()
vac_admin.head()
# Out:
#         Date   FIPS  MMWR_week       Recip_County Recip_State  \
# 0  7/31/2021  18119         30        Owen County          IN
# 1  7/31/2021  21147         30    McCreary County          KY
# 2  7/31/2021  27103         30    Nicollet County          MN
# 3  7/31/2021  19183         30  Washington County          IA
# 4  7/31/2021   8023         30    Costilla County          CO
#
#    Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# 0                     34.9                 7255                    7255
# 1                     30.9                 5326                    5326
# 2                     50.8                17399                   17354
# 3                     46.9                10308                   10307
# 4                     34.0                 1321                    1318
#
#    Series_Complete_12PlusPop_Pct  Series_Complete_18Plus  ...  \
# 0                           40.1                    7043  ...
# 1                           36.0                    5253  ...
# 2                           59.1                   16304  ...
# 3                           56.0                    9892  ...
# 4                           38.5                    1245  ...
#
#    Administered_Dose1_Recip_18Plus  Administered_Dose1_Recip_18PlusPop_Pct  \
# 0                           7403.0                                    44.9
# 1                           5836.0                                    43.1
# 2                          17333.0                                    64.8
# 3                          10442.0                                    62.9
# 4                              NaN                                     0.0
#
#    Administered_Dose1_Recip_65Plus  Administered_Dose1_Recip_65PlusPop_Pct  \
# 0                           2881.0                                    69.5
# 1                           1810.0                                    64.6
# 2                           4865.0                                    85.0
# 3                           3767.0                                    85.9
# 4                              NaN                                     0.0
#
#    SVI_CTGY  Series_Complete_Pop_Pct_SVI  Series_Complete_12PlusPop_Pct_SVI  \
# 0   Low-Mod       Low-Mod VC/Low-Mod SVI            Mod-High VC/Low-Mod SVI
# 1      High          Low-Mod VC/High SVI                Low-Mod VC/High SVI
# 2   Low-Mod          High VC/Low-Mod SVI                High VC/Low-Mod SVI
# 3       Low          Mod-High VC/Low SVI                    High VC/Low SVI
# 4      High          Low-Mod VC/High SVI                Low-Mod VC/High SVI
#
#    Series_Complete_18PlusPop_Pct_SVI  Series_Complete_65PlusPop_Pct_SVI  \
# 0            Mod-High VC/Low-Mod SVI            Mod-High VC/Low-Mod SVI
# 1                Low-Mod VC/High SVI               Mod-High VC/High SVI
# 2                High VC/Low-Mod SVI                High VC/Low-Mod SVI
# 3                    High VC/Low SVI                    High VC/Low SVI
# 4                Low-Mod VC/High SVI                    Low VC/High SVI
#
#            state_county
# 0        in_owen county
# 1    ky_mccreary county
# 2    mn_nicollet county
# 3  ia_washington county
# 4    co_costilla county
#
# [5 rows x 28 columns]

# %%
vac_h['state_county'] = vac_h['state'].str.lower() + '_' + vac_h['county'].str.lower() + ' county'
vac_h.head()
# Out:
#     county state % Estimated Hesitant or Unsure - May 26 - June 7, 2021  \
# 0  Autauga    AL                                                22%
# 1  Baldwin    AL                                                20%
# 2  Barbour    AL                                                23%
# 3     Bibb    AL                                                25%
# 4   Blount    AL                                                24%
#
#   % Estimated Hesitant-  May 26 - June 7, 2021  \
# 0                                          17%
# 1                                          15%
# 2                                          17%
# 3                                          18%
# 4                                          19%
#
#   % Estimated Strongly Hesitant-  May 26 - June 7, 2021       state_county
# 0                                                13%     al_autauga county
# 1                                                12%     al_baldwin county
# 2                                                13%     al_barbour county
# 3                                                14%        al_bibb county
# 4                                                14%      al_blount county

# %%
vac_c['state2'] = vac_c['state'].map(state_abbrev)
vac_c['state_county'] = vac_c['state2'].str.lower() + '_' + vac_c['county'].str.lower()
vac_c.head()
# Out:
#    FIPS    state          county  Th1_Historic_Undervaccination  \
# 0  1001  Alabama  Autauga County                       0.419612
# 1  1003  Alabama  Baldwin County                       0.228590
# 2  1005  Alabama  Barbour County                       0.505571
# 3  1007  Alabama     Bibb County                       0.410060
# 4  1009  Alabama   Blount County                       0.440306
#
#    Th2_Sociodemographic_Barriers  Th3_Resource_constrained_Healthcare_System  \
# 0                       0.231455                                    0.827762
# 1                       0.150271                                    0.170965
# 2                       0.991404                                    0.621777
# 3                       0.888252                                    0.335880
# 4                       0.716014                                    0.850684
#
#    Th4_Healthcare_Accessibility_Barriers  Th5_Irregular_Care_Seeking_Behavior  \
# 0                               0.484241                             0.830309
# 1                               0.391277                             0.726839
# 2                               0.966253                             0.694683
# 3                               0.842089                             0.834448
# 4                               0.580388                             0.837950
#
#        CVAC state2       state_county
# 0  0.607768     AL  al_autauga county
# 1  0.227953     AL  al_baldwin county
# 2  0.885068     AL  al_barbour county
# 3  0.764406     AL     al_bibb county
# 4  0.795288     AL   al_blount county

# %%
merg2=vac_admin.merge(vac_h,
              left_on='state_county',
              right_on='state_county')
merg2=merg2.merge(vac_c,
               left_on='state_county',
               right_on='state_county')
merg2
# Out:
#               Date FIPS_x  MMWR_week  Recip_County Recip_State  \
# 0        7/31/2021  18119         30   Owen County          IN
# 1        7/30/2021  18119         30   Owen County          IN
# 2        7/29/2021  18119         30   Owen County          IN
# 3        7/28/2021  18119         30   Owen County          IN
# 4        7/27/2021  18119         30   Owen County          IN
# ...            ...    ...        ...           ...         ...
# 691840  12/17/2020  21193         51  Perry County          KY
# 691841  12/16/2020  21193         51  Perry County          KY
# 691842  12/15/2020  21193         51  Perry County          KY
# 691843  12/14/2020  21193         51  Perry County          KY
# 691844  12/13/2020  21193         51  Perry County          KY
#
#         Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# 0                          34.9                 7255                    7255
# 1                          34.8                 7248                    7248
# 2                          34.8                 7241                    7241
# 3                          34.8                 7237                    7237
# 4                          34.8                 7228                    7228
# ...                         ...                  ...                     ...
# 691840                      0.0                    0                       0
# 691841                      0.0                    0                       0
# 691842                      0.0                    0                       0
# 691843                      0.0                    0                       0
# 691844                      0.0                    0                       0
#
#         Series_Complete_12PlusPop_Pct  Series_Complete_18Plus  ...  FIPS_y  \
# 0                                40.1                    7043  ...   18119
# 1                                40.1                    7038  ...   18119
# 2                                40.0                    7033  ...   18119
# 3                                40.0                    7029  ...   18119
# 4                                40.0                    7022  ...   18119
# ...                               ...                     ...  ...     ...
# 691840                            0.0                       0  ...   21193
# 691841                            0.0                       0  ...   21193
# 691842                            0.0                       0  ...   21193
# 691843                            0.0                       0  ...   21193
# 691844                            0.0                       0  ...   21193
#
#          state_y      county_y  Th1_Historic_Undervaccination  \
# 0        Indiana   Owen County                       0.937281
# 1        Indiana   Owen County                       0.937281
# 2        Indiana   Owen County                       0.937281
# 3        Indiana   Owen County                       0.937281
# 4        Indiana   Owen County                       0.937281
# ...          ...           ...                            ...
# 691840  Kentucky  Perry County                       0.173830
# 691841  Kentucky  Perry County                       0.173830
# 691842  Kentucky  Perry County                       0.173830
# 691843  Kentucky  Perry County                       0.173830
# 691844  Kentucky  Perry County                       0.173830
#
#         Th2_Sociodemographic_Barriers  \
# 0                            0.568927
# 1                            0.568927
# 2                            0.568927
# 3                            0.568927
# 4                            0.568927
# ...                               ...
# 691840                       0.721426
# 691841                       0.721426
# 691842                       0.721426
# 691843                       0.721426
# 691844                       0.721426
#
#         Th3_Resource_constrained_Healthcare_System  \
# 0                                         0.773639
# 1                                         0.773639
# 2                                         0.773639
# 3                                         0.773639
# 4                                         0.773639
# ...                                            ...
# 691840                                    0.329831
# 691841                                    0.329831
# 691842                                    0.329831
# 691843                                    0.329831
# 691844                                    0.329831
#
#         Th4_Healthcare_Accessibility_Barriers  \
# 0                                    0.240369
# 1                                    0.240369
# 2                                    0.240369
# 3                                    0.240369
# 4                                    0.240369
# ...                                       ...
# 691840                               0.642471
# 691841                               0.642471
# 691842                               0.642471
# 691843                               0.642471
# 691844                               0.642471
#
#         Th5_Irregular_Care_Seeking_Behavior      CVAC  state2
# 0                                  0.436485  0.659981      IN
# 1                                  0.436485  0.659981      IN
# 2                                  0.436485  0.659981      IN
# 3                                  0.436485  0.659981      IN
# 4                                  0.436485  0.659981      IN
# ...                                     ...       ...     ...
# 691840                             0.194206  0.359121      KY
# 691841                             0.194206  0.359121      KY
# 691842                             0.194206  0.359121      KY
# 691843                             0.194206  0.359121      KY
# 691844                             0.194206  0.359121      KY
#
# [691845 rows x 43 columns]

# %%
vac_c[vac_c['county']== 'Washington County']
# Out:
#        FIPS           state             county  Th1_Historic_Undervaccination  \
# 64     1129         Alabama  Washington County                       0.496339
# 182    5143        Arkansas  Washington County                       0.281121
# 305    8121        Colorado  Washington County                       0.405603
# 386   12133         Florida  Washington County                       0.996180
# 536   13303         Georgia  Washington County                       0.420567
# 594   16087           Idaho  Washington County                       0.389366
# 689   17189        Illinois  Washington County                       0.167463
# 784   18175         Indiana  Washington County                       0.923273
# 880   19183            Iowa  Washington County                       0.026106
# 988   20201          Kansas  Washington County                       0.893346
# 1107  21229        Kentucky  Washington County                       0.067813
# 1191  23029           Maine  Washington County                       0.771729
# 1213  24043        Maryland  Washington County                       0.490926
# 1395  27163       Minnesota  Washington County                       0.208851
# 1476  28151     Mississippi  Washington County                       0.838268
# 1592  29221        Missouri  Washington County                       0.858325
# 1742  31177        Nebraska  Washington County                       0.235912
# 1885  36115        New York  Washington County                       0.251194
# 1983  37187  North Carolina  Washington County                       0.596625
# 2126  39167            Ohio  Washington County                       0.071633
# 2204  40147        Oklahoma  Washington County                       0.475963
# 2241  41067          Oregon  Washington County                       0.824897
# 2306  42125    Pennsylvania  Washington County                       0.023878
# 2315  44009    Rhode Island  Washington County                       0.091691
# 2517  47179       Tennessee  Washington County                       0.854505
# 2761  48477           Texas  Washington County                       0.587711
# 2803  49053            Utah  Washington County                       0.472461
# 2817  50023         Vermont  Washington County                       0.863419
# 2910  51191        Virginia  Washington County                       0.206940
# 3113  55131       Wisconsin  Washington County                       0.040433
#
#       Th2_Sociodemographic_Barriers  \
# 64                         0.943012
# 182                        0.409105
# 305                        0.238459
# 386                        0.775868
# 536                        0.922318
# 594                        0.812480
# 689                        0.176695
# 784                        0.629099
# 880                        0.229545
# 988                        0.567972
# 1107                       0.639924
# 1191                       0.699459
# 1213                       0.445400
# 1395                       0.010825
# 1476                       0.982171
# 1592                       0.708055
# 1742                       0.004457
# 1885                       0.233047
# 1983                       0.957020
# 2126                       0.537727
# 2204                       0.305317
# 2241                       0.102833
# 2306                       0.118115
# 2315                       0.047437
# 2517                       0.225088
# 2761                       0.626234
# 2803                       0.116842
# 2817                       0.178606
# 2910                       0.335562
# 3113                       0.016874
#
#       Th3_Resource_constrained_Healthcare_System  \
# 64                                      0.717287
# 182                                     0.128303
# 305                                     0.758994
# 386                                     0.893028
# 536                                     0.695320
# 594                                     0.273480
# 689                                     0.299586
# 784                                     0.583254
# 880                                     0.161414
# 988                                     0.628781
# 1107                                    0.291945
# 1191                                    0.021968
# 1213                                    0.104744
# 1395                                    0.443808
# 1476                                    0.483604
# 1592                                    0.737026
# 1742                                    0.362623
# 1885                                    0.323464
# 1983                                    0.870742
# 2126                                    0.447310
# 2204                                    0.368036
# 2241                                    0.413881
# 2306                                    0.228908
# 2315                                    0.123528
# 2517                                    0.151544
# 2761                                    0.846546
# 2803                                    0.435212
# 2817                                    0.004776
# 2910                                    0.167781
# 3113                                    0.620503
#
#       Th4_Healthcare_Accessibility_Barriers  \
# 64                                 0.556192
# 182                                0.630372
# 305                                0.225406
# 386                                0.753900
# 536                                0.941102
# 594                                0.836995
# 689                                0.116842
# 784                                0.636422
# 880                                0.165871
# 988                                0.125756
# 1107                               0.369946
# 1191                               0.858962
# 1213                               0.468641
# 1395                               0.010825
# 1476                               0.992359
# 1592                               0.801656
# 1742                               0.190704
# 1885                               0.370264
# 1983                               0.960840
# 2126                               0.440942
# 2204                               0.774594
# 2241                               0.276982
# 2306                               0.301496
# 2315                               0.006686
# 2517                               0.589940
# 2761                               0.777141
# 2803                               0.332060
# 2817                               0.315823
# 2910                               0.331423
# 3113                               0.044890
#
#       Th5_Irregular_Care_Seeking_Behavior      CVAC state2  \
# 64                               0.822350  0.822350     AL
# 182                              0.863419  0.445718     AR
# 305                              0.411016  0.349570     CO
# 386                              0.712512  0.952245     FL
# 536                              0.622095  0.836995     GA
# 594                              0.667622  0.667940     ID
# 689                              0.560013  0.127030     IL
# 784                              0.485196  0.750716     IN
# 880                              0.014008  0.012098     IA
# 988                              0.181789  0.473098     KS
# 1107                             0.157593  0.184336     KY
# 1191                             0.114932  0.495702     ME
# 1213                             0.303088  0.276663     MD
# 1395                             0.495065  0.091691     MN
# 1476                             0.787329  0.943649     MS
# 1592                             0.567335  0.858007     MO
# 1742                             0.447628  0.108564     NE
# 1885                             0.342884  0.183699     NY
# 1983                             0.342248  0.871379     NC
# 2126                             0.041706  0.188475     OH
# 2204                             0.424387  0.458771     OK
# 2241                             0.715696  0.452722     OR
# 2306                             0.146132  0.033429     PA
# 2315                             0.000955  0.000318     RI
# 2517                             0.730022  0.525629     TN
# 2761                             0.843044  0.860554     TX
# 2803                             0.687679  0.351480     UT
# 2817                             0.115568  0.173193     VT
# 2910                             0.057943  0.074817     VA
# 3113                             0.263610  0.056033     WI
#
#               state_county
# 64    al_washington county
# 182   ar_washington county
# 305   co_washington county
# 386   fl_washington county
# 536   ga_washington county
# 594   id_washington county
# 689   il_washington county
# 784   in_washington county
# 880   ia_washington county
# 988   ks_washington county
# 1107  ky_washington county
# 1191  me_washington county
# 1213  md_washington county
# 1395  mn_washington county
# 1476  ms_washington county
# 1592  mo_washington county
# 1742  ne_washington county
# 1885  ny_washington county
# 1983  nc_washington county
# 2126  oh_washington county
# 2204  ok_washington county
# 2241  or_washington county
# 2306  pa_washington county
# 2315  ri_washington county
# 2517  tn_washington county
# 2761  tx_washington county
# 2803  ut_washington county
# 2817  vt_washington county
# 2910  va_washington county
# 3113  wi_washington county

# %% [markdown]
# # Population

# %%
pop.columns=['state','county','population']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-173030ee584e> in <module>
# ----> 1 pop.columns=['state','county','population']
#
# NameError: name 'pop' is not defined

# %%
pop['st']=pop['state'].map(state_abbrev)
pop['st_cty']=pop['st']+' '+pop['county']

# %%
pop=pop[['st_cty','population']]
pop

# %%
print('pop shape {} \n'.format(pop.shape))

county_list=pop['county'].tolist()
pop['st_cty']=pop['state']+

len(county_list)

# %% [markdown]
# # Vaccination status

# %%
vac_admin.columns

# %%
vac_admin['Administered_Dose1_Pop_Pct'].sort_values(ascending=False)

# %%
temp=vac_admin.groupby(['Recip_State','Recip_County'])['Administered_Dose1_Pop_Pct'].agg('max')

temp=temp.reset_index()
temp['st_cty']=temp['Recip_State']+' '+temp['Recip_County']
vac=temp[['st_cty','Administered_Dose1_Pop_Pct']]
vac.columns=['st_cty','vac_rate']
vac
# Out:
#                              st_cty  vac_rate
# 0         AK Aleutians East Borough      72.3
# 1     AK Aleutians West Census Area      61.5
# 2         AK Anchorage Municipality      55.6
# 3             AK Bethel Census Area      56.5
# 4            AK Bristol Bay Borough      99.9
# ...                             ...       ...
# 3277                WY Teton County      82.0
# 3278                WY Uinta County      37.2
# 3279              WY Unknown County       0.0
# 3280             WY Washakie County      33.8
# 3281               WY Weston County      29.4
#
# [3282 rows x 2 columns]

# %% [markdown]
# # Vaccine hesitation

# %%
cty_name=list(vac['st_cty'])

def cty_match(x,y):
    for name in cty_name:
        if x in name:
            if y in name:
                return(name)
                        
#to test:
cty_match('Harris','TX')
# Out:
# 'TX Harris County'

# %%
vac['st_cty']
# Out:
# 0           AK Aleutians East Borough
# 1       AK Aleutians West Census Area
# 2           AK Anchorage Municipality
# 3               AK Bethel Census Area
# 4              AK Bristol Bay Borough
#                     ...
# 3277                  WY Teton County
# 3278                  WY Uinta County
# 3279                WY Unknown County
# 3280               WY Washakie County
# 3281                 WY Weston County
# Name: st_cty, Length: 3282, dtype: object

# %%
vac_h.T
# Out:
#                                                                  0     \
# county                                                        Autauga
# state                                                              AL
# % Estimated Hesitant or Unsure - May 26 - June ...                22%
# % Estimated Hesitant-  May 26 - June 7, 2021                      17%
# % Estimated Strongly Hesitant-  May 26 - June 7...                13%
# state_county                                        al_autauga county
#
#                                                                  1     \
# county                                                        Baldwin
# state                                                              AL
# % Estimated Hesitant or Unsure - May 26 - June ...                20%
# % Estimated Hesitant-  May 26 - June 7, 2021                      15%
# % Estimated Strongly Hesitant-  May 26 - June 7...                12%
# state_county                                        al_baldwin county
#
#                                                                  2     \
# county                                                        Barbour
# state                                                              AL
# % Estimated Hesitant or Unsure - May 26 - June ...                23%
# % Estimated Hesitant-  May 26 - June 7, 2021                      17%
# % Estimated Strongly Hesitant-  May 26 - June 7...                13%
# state_county                                        al_barbour county
#
#                                                               3     \
# county                                                        Bibb
# state                                                           AL
# % Estimated Hesitant or Unsure - May 26 - June ...             25%
# % Estimated Hesitant-  May 26 - June 7, 2021                   18%
# % Estimated Strongly Hesitant-  May 26 - June 7...             14%
# state_county                                        al_bibb county
#
#                                                                 4     \
# county                                                        Blount
# state                                                             AL
# % Estimated Hesitant or Unsure - May 26 - June ...               24%
# % Estimated Hesitant-  May 26 - June 7, 2021                     19%
# % Estimated Strongly Hesitant-  May 26 - June 7...               14%
# state_county                                        al_blount county
#
#                                                                  5     \
# county                                                        Bullock
# state                                                              AL
# % Estimated Hesitant or Unsure - May 26 - June ...                23%
# % Estimated Hesitant-  May 26 - June 7, 2021                      17%
# % Estimated Strongly Hesitant-  May 26 - June 7...                13%
# state_county                                        al_bullock county
#
#                                                                 6     \
# county                                                        Butler
# state                                                             AL
# % Estimated Hesitant or Unsure - May 26 - June ...               23%
# % Estimated Hesitant-  May 26 - June 7, 2021                     18%
# % Estimated Strongly Hesitant-  May 26 - June 7...               13%
# state_county                                        al_butler county
#
#                                                                  7     \
# county                                                        Calhoun
# state                                                              AL
# % Estimated Hesitant or Unsure - May 26 - June ...                24%
# % Estimated Hesitant-  May 26 - June 7, 2021                      18%
# % Estimated Strongly Hesitant-  May 26 - June 7...                14%
# state_county                                        al_calhoun county
#
#                                                                   8     \
# county                                                        Chambers
# state                                                               AL
# % Estimated Hesitant or Unsure - May 26 - June ...                 24%
# % Estimated Hesitant-  May 26 - June 7, 2021                       18%
# % Estimated Strongly Hesitant-  May 26 - June 7...                 14%
# state_county                                        al_chambers county
#
#                                                                   9     ...  \
# county                                                        Cherokee  ...
# state                                                               AL  ...
# % Estimated Hesitant or Unsure - May 26 - June ...                 24%  ...
# % Estimated Hesitant-  May 26 - June 7, 2021                       18%  ...
# % Estimated Strongly Hesitant-  May 26 - June 7...                 14%  ...
# state_county                                        al_cherokee county  ...
#
#                                                                   3133  \
# county                                                        Niobrara
# state                                                               WY
# % Estimated Hesitant or Unsure - May 26 - June ...                 29%
# % Estimated Hesitant-  May 26 - June 7, 2021                       23%
# % Estimated Strongly Hesitant-  May 26 - June 7...                 17%
# state_county                                        wy_niobrara county
#
#                                                               3134  \
# county                                                        Park
# state                                                           WY
# % Estimated Hesitant or Unsure - May 26 - June ...             27%
# % Estimated Hesitant-  May 26 - June 7, 2021                   21%
# % Estimated Strongly Hesitant-  May 26 - June 7...             15%
# state_county                                        wy_park county
#
#                                                                 3135  \
# county                                                        Platte
# state                                                             WY
# % Estimated Hesitant or Unsure - May 26 - June ...               29%
# % Estimated Hesitant-  May 26 - June 7, 2021                     23%
# % Estimated Strongly Hesitant-  May 26 - June 7...               17%
# state_county                                        wy_platte county
#
#                                                                   3136  \
# county                                                        Sheridan
# state                                                               WY
# % Estimated Hesitant or Unsure - May 26 - June ...                 27%
# % Estimated Hesitant-  May 26 - June 7, 2021                       21%
# % Estimated Strongly Hesitant-  May 26 - June 7...                 15%
# state_county                                        wy_sheridan county
#
#                                                                   3137  \
# county                                                        Sublette
# state                                                               WY
# % Estimated Hesitant or Unsure - May 26 - June ...                 28%
# % Estimated Hesitant-  May 26 - June 7, 2021                       22%
# % Estimated Strongly Hesitant-  May 26 - June 7...                 16%
# state_county                                        wy_sublette county
#
#                                                                     3138  \
# county                                                        Sweetwater
# state                                                                 WY
# % Estimated Hesitant or Unsure - May 26 - June ...                   28%
# % Estimated Hesitant-  May 26 - June 7, 2021                         22%
# % Estimated Strongly Hesitant-  May 26 - June 7...                   16%
# state_county                                        wy_sweetwater county
#
#                                                                3139  \
# county                                                        Teton
# state                                                            WY
# % Estimated Hesitant or Unsure - May 26 - June ...              27%
# % Estimated Hesitant-  May 26 - June 7, 2021                    21%
# % Estimated Strongly Hesitant-  May 26 - June 7...              15%
# state_county                                        wy_teton county
#
#                                                                3140  \
# county                                                        Uinta
# state                                                            WY
# % Estimated Hesitant or Unsure - May 26 - June ...              28%
# % Estimated Hesitant-  May 26 - June 7, 2021                    22%
# % Estimated Strongly Hesitant-  May 26 - June 7...              16%
# state_county                                        wy_uinta county
#
#                                                                   3141  \
# county                                                        Washakie
# state                                                               WY
# % Estimated Hesitant or Unsure - May 26 - June ...                 29%
# % Estimated Hesitant-  May 26 - June 7, 2021                       23%
# % Estimated Strongly Hesitant-  May 26 - June 7...                 17%
# state_county                                        wy_washakie county
#
#                                                                 3142
# county                                                        Weston
# state                                                             WY
# % Estimated Hesitant or Unsure - May 26 - June ...               29%
# % Estimated Hesitant-  May 26 - June 7, 2021                     23%
# % Estimated Strongly Hesitant-  May 26 - June 7...               17%
# state_county                                        wy_weston county
#
# [6 rows x 3143 columns]

# %%
def f(x):
    return cty_match(x['county'],x['state'])

vac_h.T.apply(f)
# Out:
# 0          AL Autauga County
# 1          AL Baldwin County
# 2          AL Barbour County
# 3             AL Bibb County
# 4           AL Blount County
#                 ...
# 3138    WY Sweetwater County
# 3139         WY Teton County
# 3140         WY Uinta County
# 3141      WY Washakie County
# 3142        WY Weston County
# Length: 3143, dtype: object

# %%
vac_h['st_cty']=vac_h[['state','county']].apply(cty_match)

# %%
vac_h[['state','county']].apply

# %%
vac_c['st']=vac_c['state'].map(state_abbrev)
vac_c['st_cty']=vac_c['st']+' '+vac_c['county']
temp1=vac_c[['st_cty',
             'Th1_Historic_Undervaccination',
             'Th2_Sociodemographic_Barriers',
             'Th3_Resource_constrained_Healthcare_System',
             'Th4_Healthcare_Accessibility_Barriers',
             'Th5_Irregular_Care_Seeking_Behavior']]
temp1
# Out:
#                     st_cty  Th1_Historic_Undervaccination  \
# 0        AL Autauga County                       0.419612
# 1        AL Baldwin County                       0.228590
# 2        AL Barbour County                       0.505571
# 3           AL Bibb County                       0.410060
# 4         AL Blount County                       0.440306
# ...                    ...                            ...
# 3137  WY Sweetwater County                       0.951926
# 3138       WY Teton County                       0.913403
# 3139       WY Uinta County                       0.942057
# 3140    WY Washakie County                       0.980579
# 3141      WY Weston County                       0.991404
#
#       Th2_Sociodemographic_Barriers  \
# 0                          0.231455
# 1                          0.150271
# 2                          0.991404
# 3                          0.888252
# 4                          0.716014
# ...                             ...
# 3137                       0.201210
# 3138                       0.115568
# 3139                       0.152499
# 3140                       0.375040
# 3141                       0.090099
#
#       Th3_Resource_constrained_Healthcare_System  \
# 0                                       0.827762
# 1                                       0.170965
# 2                                       0.621777
# 3                                       0.335880
# 4                                       0.850684
# ...                                          ...
# 3137                                    0.318370
# 3138                                    0.021331
# 3139                                    0.049666
# 3140                                    0.168099
# 3141                                    0.216173
#
#       Th4_Healthcare_Accessibility_Barriers  \
# 0                                  0.484241
# 1                                  0.391277
# 2                                  0.966253
# 3                                  0.842089
# 4                                  0.580388
# ...                                     ...
# 3137                               0.264565
# 3138                               0.314550
# 3139                               0.353709
# 3140                               0.642789
# 3141                               0.306909
#
#       Th5_Irregular_Care_Seeking_Behavior
# 0                                0.830309
# 1                                0.726839
# 2                                0.694683
# 3                                0.834448
# 4                                0.837950
# ...                                   ...
# 3137                             0.923910
# 3138                             0.923591
# 3139                             0.913085
# 3140                             0.899713
# 3141                             0.912130
#
# [3142 rows x 6 columns]

# %%
vac_c_sub['st']=vac_c['state'].map(state_abbrev)
vac_c_sub['st_cty']=vac_c['st']+' '+vac_c['county']
vac_c_sub.columns
temp2=vac_c_sub[['st_cty',
                 'Th1_Lower Coverage and Higher Refusal Rates',
       'Th2_Lack of Access to Infomation',
       'Th2_Socio-economically disadvantaged',
       'Th3_Low Healthcare System Capacity', 'Th3_Weak Healthcare System',
       'Th4_Barriers due to cost', 'Th4_Barriers due to Transportation',
       'Th5_Lack of Designated Medical Home',
       'Th5_Lack of Routine Care Visits',
                ]]
temp2
# Out:
#                     st_cty  Th1_Lower Coverage and Higher Refusal Rates  \
# 0        AL Autauga County                                     0.419612
# 1        AL Baldwin County                                     0.228590
# 2        AL Barbour County                                     0.505571
# 3           AL Bibb County                                     0.410060
# 4         AL Blount County                                     0.440306
# ...                    ...                                          ...
# 3137  WY Sweetwater County                                     0.951926
# 3138       WY Teton County                                     0.913403
# 3139       WY Uinta County                                     0.942057
# 3140    WY Washakie County                                     0.980579
# 3141      WY Weston County                                     0.991404
#
#       Th2_Lack of Access to Infomation  Th2_Socio-economically disadvantaged  \
# 0                             0.170646                              0.359440
# 1                             0.154091                              0.228590
# 2                             0.970710                              0.971665
# 3                             0.827443                              0.870423
# 4                             0.850366                              0.522445
# ...                                ...                                   ...
# 3137                          0.148997                              0.327921
# 3138                          0.212034                              0.101560
# 3139                          0.012098                              0.375677
# 3140                          0.521808                              0.260745
# 3141                          0.117797                              0.147087
#
#       Th3_Low Healthcare System Capacity  Th3_Weak Healthcare System  \
# 0                               0.682267                    0.744031
# 1                               0.243235                    0.312639
# 2                               0.556829                    0.594715
# 3                               0.125756                    0.680675
# 4                               0.923273                    0.544731
# ...                                  ...                         ...
# 3137                            0.753900                    0.026425
# 3138                            0.143903                    0.036613
# 3139                            0.262655                    0.023241
# 3140                            0.480102                    0.072907
# 3141                            0.611270                    0.029290
#
#       Th4_Barriers due to cost  Th4_Barriers due to Transportation  \
# 0                     0.660936                            0.320280
# 1                     0.740528                            0.117797
# 2                     0.842407                            0.946514
# 3                     0.818211                            0.645018
# 4                     0.821394                            0.267749
# ...                        ...                                 ...
# 3137                  0.645336                            0.051576
# 3138                  0.684177                            0.083731
# 3139                  0.640560                            0.172875
# 3140                  0.738300                            0.423750
# 3141                  0.664438                            0.092009
#
#       Th5_Lack of Designated Medical Home  Th5_Lack of Routine Care Visits
# 0                                0.756129                         0.736390
# 1                                0.690544                         0.588348
# 2                                0.789876                         0.447310
# 3                                0.787966                         0.715059
# 4                                0.735753                         0.783190
# ...                                   ...                              ...
# 3137                             0.953200                         0.808341
# 3138                             0.951289                         0.809933
# 3139                             0.938555                         0.800382
# 3140                             0.931550                         0.777778
# 3141                             0.939191                         0.797835
#
# [3142 rows x 10 columns]

# %%
vac_2model=temp.merge(temp1,
                    on='st_cty')
vac_2model
# Out:
#      Recip_State                Recip_County  Administered_Dose1_Pop_Pct  \
# 0             AK      Aleutians East Borough                        72.3
# 1             AK  Aleutians West Census Area                        61.5
# 2             AK      Anchorage Municipality                        55.6
# 3             AK          Bethel Census Area                        56.5
# 4             AK         Bristol Bay Borough                        99.9
# ...          ...                         ...                         ...
# 3134          WY           Sweetwater County                        37.1
# 3135          WY                Teton County                        82.0
# 3136          WY                Uinta County                        37.2
# 3137          WY             Washakie County                        33.8
# 3138          WY               Weston County                        29.4
#
#                              st_cty  Th1_Historic_Undervaccination  \
# 0         AK Aleutians East Borough                       0.964661
# 1     AK Aleutians West Census Area                       0.967845
# 2         AK Anchorage Municipality                       0.789239
# 3             AK Bethel Census Area                       0.998408
# 4            AK Bristol Bay Borough                       0.886979
# ...                             ...                            ...
# 3134           WY Sweetwater County                       0.951926
# 3135                WY Teton County                       0.913403
# 3136                WY Uinta County                       0.942057
# 3137             WY Washakie County                       0.980579
# 3138               WY Weston County                       0.991404
#
#       Th2_Sociodemographic_Barriers  \
# 0                          0.686406
# 1                          0.372811
# 2                          0.129258
# 3                          0.853231
# 4                          0.172557
# ...                             ...
# 3134                       0.201210
# 3135                       0.115568
# 3136                       0.152499
# 3137                       0.375040
# 3138                       0.090099
#
#       Th3_Resource_constrained_Healthcare_System  \
# 0                                       0.121936
# 1                                       0.033110
# 2                                       0.108564
# 3                                       0.009233
# 4                                       0.006686
# ...                                          ...
# 3134                                    0.318370
# 3135                                    0.021331
# 3136                                    0.049666
# 3137                                    0.168099
# 3138                                    0.216173
#
#       Th4_Healthcare_Accessibility_Barriers  \
# 0                                  0.975167
# 1                                  0.957020
# 2                                  0.515759
# 3                                  0.968163
# 4                                  0.960522
# ...                                     ...
# 3134                               0.264565
# 3135                               0.314550
# 3136                               0.353709
# 3137                               0.642789
# 3138                               0.306909
#
#       Th5_Irregular_Care_Seeking_Behavior
# 0                                0.983445
# 1                                0.984400
# 2                                0.966253
# 3                                0.978669
# 4                                0.977714
# ...                                   ...
# 3134                             0.923910
# 3135                             0.923591
# 3136                             0.913085
# 3137                             0.899713
# 3138                             0.912130
#
# [3139 rows x 9 columns]

# %%
vac_2model.sort_values(by='vac_rate',ascending=False)

# %% [markdown]
# # Linear regression

# %%
# Special packages
import statsmodels.api as sm
from patsy import dmatrices


y, X = dmatrices('vac_rate ~ Th1_Historic_Undervaccination + Th2_Sociodemographic_Barriers + Th3_Resource_constrained_Healthcare_System +Th4_Healthcare_Accessibility_Barriers+Th5_Irregular_Care_Seeking_Behavior', data=vac_2model, return_type='dataframe')


model = sm.OLS(y, X)       # Set up the model
result = model.fit()       # Fit model (find the intercept and slopes)
print(result.summary())

# %%
# Special packages
import statsmodels.api as sm
from patsy import dmatrices


y, X = dmatrices('Administered_Dose1_Pop_Pct ~ Th1_Historic_Undervaccination + Th2_Sociodemographic_Barriers + Th3_Resource_constrained_Healthcare_System +Th5_Irregular_Care_Seeking_Behavior', data=vac_2model, return_type='dataframe')


model = sm.OLS(y, X)       # Set up the model
result = model.fit()       # Fit model (find the intercept and slopes)
print(result.summary())

# %%
# Special packages
import statsmodels.api as sm
from patsy import dmatrices


y, X = dmatrices('Administered_Dose1_Pop_Pct ~ CVAC', data=vac_2model, return_type='dataframe')


model = sm.OLS(y, X)       # Set up the model
result = model.fit()       # Fit model (find the intercept and slopes)
print(result.summary())

# %% [markdown]
# # Random Forest
